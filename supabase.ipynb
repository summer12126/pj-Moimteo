# %%
import os
from dotenv import load_dotenv
from supabase import create_client, Client

load_dotenv()

url = os.getenv("SUPABASE_URL")
key = os.getenv("SUPABASE_KEY")

supabase = create_client(url, key)

# %%
import pandas as pd
result = supabase.table("rental_spaces").select("*").execute()
data = result.data
df_rentalspaces = pd.DataFrame(data)

# %%
df_rentalspaces
# Out:
#     id                       name address  latitude  longitude  \
# 0    2                  용산도시기억전시관    None   37.5264    126.967
# 1    3  신도림동 주민센터  >신도림동주민센터 문화교실    None   37.5078    126.881
# 2    4                고척2동 주민센터      None   37.5067    126.859
# 3    5                  고척1동 주민센터    None   37.5004    126.863
# 4    6                   구로3동주민센터    None   37.4873    126.890
# 5    7                   구로3동주민센터    None   37.4873    126.890
# 6    8               청소년 아지트 "다온"    None   37.4837    127.125
# 7    9                  개봉3동 주민센터    None   37.4860    126.854
# 8   10                  용산도시기억전시관    None   37.5264    126.967
# 9   11  신도림동 주민센터  >신도림동주민센터 문화교실    None   37.5078    126.881
# 10  12                 구로1동 주민센터     None   37.4930    126.876
# 11  13                  고척1동 주민센터    None   37.5004    126.863
# 12  14                   구로3동주민센터    None   37.4873    126.890
# 13  15                   구로3동주민센터    None   37.4873    126.890
# 14  16                   구로3동주민센터    None   37.4873    126.890
# 15  17    북아현동 주민센터>3층 강의실(지혜나눔방)    None   37.5595    126.957
# 16  18    북아현동 주민센터>3층 강의실(취미교양실)    None   37.5595    126.957
# 17  19   중랑생활문화센터>중랑생활문화센터(커뮤니티룸)    None   37.6118    127.078
#
#                       telephone  \
# 0                  02-3785-2590
# 1                  02-2620-7104
# 2                  02-2620-7906
# 3                  02-2620-7804
# 4                  02-2620-7422
# 5                  02-2620-7403
# 6   02-3402-1318, 010-4438-1318
# 7                  02-2620-7369
# 8                  02-3785-2590
# 9                  02-2620-7104
# 10                 02-2620-7204
# 11                 02-2620-7804
# 12                 02-2620-7407
# 13                 02-2620-7407
# 14                 02-2620-7407
# 15                  02-330-6763
# 16                  02-330-6763
# 17                  02-971-0420
#
#                                              homepage capacity category  \
# 0   https://yeyak.seoul.go.kr/web/reservation/sele...     None      회의실
# 1   https://yeyak.seoul.go.kr/web/reservation/sele...     None      회의실
# 2   https://yeyak.seoul.go.kr/web/reservation/sele...     None      회의실
# 3   https://yeyak.seoul.go.kr/web/reservation/sele...     None      강의실
# 4   https://yeyak.seoul.go.kr/web/reservation/sele...     None      강의실
# 5   https://yeyak.seoul.go.kr/web/reservation/sele...     None      강의실
# 6   https://yeyak.seoul.go.kr/web/reservation/sele...     None      회의실
# 7   https://yeyak.seoul.go.kr/web/reservation/sele...     None      회의실
# 8   https://yeyak.seoul.go.kr/web/reservation/sele...     None      회의실
# 9   https://yeyak.seoul.go.kr/web/reservation/sele...     None      회의실
# 10  https://yeyak.seoul.go.kr/web/reservation/sele...     None      회의실
# 11  https://yeyak.seoul.go.kr/web/reservation/sele...     None      강의실
# 12  https://yeyak.seoul.go.kr/web/reservation/sele...     None      강의실
# 13  https://yeyak.seoul.go.kr/web/reservation/sele...     None      강의실
# 14  https://yeyak.seoul.go.kr/web/reservation/sele...     None      강의실
# 15  https://yeyak.seoul.go.kr/web/reservation/sele...     None      강의실
# 16  https://yeyak.seoul.go.kr/web/reservation/sele...     None      강의실
# 17  https://yeyak.seoul.go.kr/web/reservation/sele...     None      회의실
#
#                           created_at
# 0   2025-02-18T16:04:56.555215+00:00
# 1   2025-02-18T16:04:56.555215+00:00
# 2   2025-02-18T16:04:56.555215+00:00
# 3   2025-02-18T16:04:56.555215+00:00
# 4   2025-02-18T16:04:56.555215+00:00
# 5   2025-02-18T16:04:56.555215+00:00
# 6   2025-02-18T16:04:56.555215+00:00
# 7   2025-02-18T16:04:56.555215+00:00
# 8   2025-02-18T16:04:56.555215+00:00
# 9   2025-02-18T16:04:56.555215+00:00
# 10  2025-02-18T16:04:56.555215+00:00
# 11  2025-02-18T16:04:56.555215+00:00
# 12  2025-02-18T16:04:56.555215+00:00
# 13  2025-02-18T16:04:56.555215+00:00
# 14  2025-02-18T16:04:56.555215+00:00
# 15  2025-02-18T16:04:56.555215+00:00
# 16  2025-02-18T16:04:56.555215+00:00
# 17  2025-02-18T16:04:56.555215+00:00
